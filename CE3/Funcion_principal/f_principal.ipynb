# %% [markdown]
# # Búsquedas informadas - A*

# %% [markdown]
# ## Problema a resolver

# %% [markdown]
# Vamos a recorrer el siguiente grafo desde Salida hasta Objetivo.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ## Representación del problema

# %%
mapa = {
    'Salida': [('A', 6), ('B', 5), ('C', 10)],
    'A': [('E', 6)],
    'B': [('E', 6), ('D', 7)],
    'C': [('D', 6)],
    'E': [('F', 4)],
    'D': [('F', 6)],
    'F': [('Objetivo', 3)]
}
heuristica = {
    'Salida': 17,
    'A': 10,
    'B': 13,
    'C': 4,
    'D': 2,
    'E': 4,
    'F': 1,
    'Objetivo': 0
}

# %% [markdown]
# ## 1. Recorre el mapa para obtener los sucesores de X

# %%
x = 'Salida'
# Out:
# Salida a   A
# Salida a   B
# Salida a   C

# %% [markdown]
# ## 2. Recorre el mapa heurística para obtener el valor de x

# %% [markdown]
# ## Representación de los estados

# %% [markdown]
# **Utiliza la clase Nodo de tu práctica**
# para que a la hora de hacer la función de expandir no falles.

# %% [markdown]
# ## 3. Rellena la función heuristic_search en GraphSearch siguiendo las indicaciones de los números.

# %%
def fx_Camino(nodo_actual):

    ruta = []
    #print(nodo_actual.get_estado())
    ruta.append(nodo_actual.get_estado())

    padre_node = nodo_actual.get_padre()
    #print(padre_node.get_estado())

    # recorrer hasta llegar al origen
    while padre_node is not None:

        ruta.append(padre_node.get_estado())

        padre_node=padre_node.get_padre()
        #print(padre_node)
    
    return ruta

# %%
# Definición de la función principal
def heuristic_search(initial_state, goal_state):


    # 1. Crear un nodo con el estado inicial del problema

    # 2. Insertar el nodo inicial en la estructura de datos FRONTIER
    # 3. Inicializar la lista EXPANDED como vacía

    # 4. Mientras el estado final no sea encontrado y FRONTIER no esté vacía:
 
        # 4.1 Remover el primer nodo de FRONTIER
        # 4.2 Si el nodo contiene el estado final:
            
        # 4.3 Si el nodo no contiene el estado final:
            # 4.3.1 Insertar el estado del nodo en EXPANDED
            # 4.3.2 Expandir los sucesores del nodo
            sucesores = expand_node()

            # 4.3.2.2 Recorrer los sucesores            
                
                # 4.3.3 Insertar los nodos sucesores en FRONTIER (si no están en FRONTIER o EXPANDED)

            # 4.3.4 Ordenar FRONTIER en orden ascendente según f(n) (f(n) = costo acumulado + h(n))

    # 5. Si se encuentra el estado final:

        # Aquí empieza la reconstrucción de la ruta 
        # PON EL NOMBRE QUE HAYAS PUESTO EN EL PASO 4.1
        ruta_auxiliar = fx_Camino()

        # Invertir la ruta para que empiece desde el origen
        ruta_auxiliar.reverse()

        # Mostrar la ruta y el costo total
        print("Ruta:", " -> ".join(ruta_auxiliar))
    # Retornar la secuencia de acciones encontradas
    # 6. Si NO se encuentra el estado final:
